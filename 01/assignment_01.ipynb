# %% [markdown]
# #Machine Learning Project - Assignment 01
# ##LaTeX exercise
# ###CAUCSE senior 20151145 Kim Jekyun

# %% [markdown]
# (1) $ f\left({x}\right) = ax^2 + bx + c $
#
# (2) $ f\left({x}\right) = \exp\left(x\right) $
#
# (3) $ f\left({x}\right) =\ _{b}^{a},\quad a\in\mathbb{R},\ b\in\mathbb{R}$
#
# (4) $ f\left({x}\right) = \sum_{i=1}^{n}{x_i},\quad {x}=\left({x_1},{x_2},{\cdots},{x_n}\right) $
#
# (5) $ f\left({x}\right) = \int_{\Omega}{\sigma\left({x},{t}\right)dt} $
#
# (6) $ _{\partial\omega}^{\partial\mathbb{E}} $
