# %% [markdown]
# #Machine Learning Project
# ##Assignment 07 - K-means clustering
# ###CAUCSE senior 20151145 Kim Jekyun

# %% [markdown]
# ##COMPUTING AREA

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('data-kmeans.csv')
data = dataset.values

# %% [markdown]
# ##RESULT AREA
